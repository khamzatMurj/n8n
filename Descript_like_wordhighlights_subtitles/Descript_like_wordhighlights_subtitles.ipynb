# %% [markdown]
# <a href="https://colab.research.google.com/github/khamzatMurj/n8n/blob/transcript/Descript_like_wordhighlights_subtitles/Descript_like_wordhighlights_subtitles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Code and files for this notebook: https://github.com/ramsrigouthamg/Supertranslate.ai/tree/main/Descript_like_wordhighlights_subtitles
#
# Author: [Ramsri Goutham](https://twitter.com/ramsri_goutham)

# %% [markdown]
# https://www.youtube.com/watch?v=LWrRJx2wdWc

# %%
# !pip install --quiet ipython-autotime --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 42.2 MB/s eta 0:00:00

# %%
# %load_ext autotime
# Out:
# time: 519 µs (started: 2025-03-28 14:03:10 +00:00)

# %% [markdown]
# ## Step1: Download video or upload the video in mp4 format that you want to convert to fancy word-level subtitles (audiogram)

# %%
import os

# mp4videoURL = "https://github.com/ramsrigouthamg/Supertranslate.ai/raw/main/Descript_like_wordhighlights_subtitles/Intro.mp4"
mp4videoURL = "./N8n/short.mp4"
# videofilename = mp4videoURL.split('/')[-1]
# print (videofilename)
videofilename = "./N8n/short.mp4"
# Out:
# time: 649 µs (started: 2025-03-28 14:03:58 +00:00)

# %% [markdown]
# ## Step2: Extract audio (mp3) from the video file

# %%
# !pip install ffmpeg-python==0.2.0 --quiet
# Out:
# time: 3.22 s (started: 2025-03-28 14:03:34 +00:00)

# %%
import ffmpeg

audiofilename = videofilename.replace(".mp4",'.mp3')

# Create the ffmpeg input stream
input_stream = ffmpeg.input(videofilename)

# Extract the audio stream from the input stream
audio = input_stream.audio

# Save the audio stream as an MP3 file
output_stream = ffmpeg.output(audio, audiofilename)

# Overwrite output file if it already exists
output_stream = ffmpeg.overwrite_output(output_stream)

ffmpeg.run(output_stream)

print (audiofilename)
# Out:
# ./N8n/short.mp3
# time: 1.52 s (started: 2025-03-28 14:04:01 +00:00)

# %%
from IPython.display import Audio

Audio(audiofilename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# time: 12.9 ms (started: 2025-03-28 14:04:06 +00:00)

# %% [markdown]
# ## Step3: Get word-level transcription (speech-to-text) from audio using OpenAI's Whisper

# %%
# !pip install assemblyai --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.2/44.2 kB 3.0 MB/s eta 0:00:00
# time: 3.72 s (started: 2025-03-28 14:04:20 +00:00)

# %%
import assemblyai as aai
# Out:
# time: 549 µs (started: 2025-03-28 14:06:43 +00:00)

# %%
import assemblyai as aai

aai.settings.api_key = "7c9abc7d319244a1bfb7a18b21343cc0"
aai.settings.base_url = "https://api.eu.assemblyai.com"


audio_file = "./N8n/short.mp3"
# audio_file = "https://assembly.ai/wildfires.mp3"

#    1005                 "If `auto_chapters` is enabled, then `punctuate` must not be disabled"
# config = aai.TranscriptionConfig(auto_chapters=True, speaker_labels=True, punctuate=False, format_text=False)
config = aai.TranscriptionConfig(auto_chapters=True, speaker_labels=True)



transcript = aai.Transcriber(config=config).transcribe(audio_file)

if transcript.status == "error":
  raise RuntimeError(f"Transcription failed: {transcript.error}")

print(transcript.text)
# Out:
# Like all of a sudden I'd be trying to prove that I'm not crazy when I knew I wasn't crazy.
# time: 16.9 s (started: 2025-03-28 14:07:38 +00:00)

# %%
print(transcript.json_response['words'])
# Out:
# [{'text': 'Like', 'start': 160, 'end': 272, 'confidence': 0.98641, 'speaker': 'A', 'channel': None}, {'text': 'all', 'start': 272, 'end': 408, 'confidence': 0.9999, 'speaker': 'A', 'channel': None}, {'text': 'of', 'start': 416, 'end': 504, 'confidence': 0.99806, 'speaker': 'A', 'channel': None}, {'text': 'a', 'start': 512, 'end': 584, 'confidence': 0.9987, 'speaker': 'A', 'channel': None}, {'text': 'sudden', 'start': 592, 'end': 776, 'confidence': 0.99997, 'speaker': 'A', 'channel': None}, {'text': "I'd", 'start': 808, 'end': 968, 'confidence': 0.98048, 'speaker': 'A', 'channel': None}, {'text': 'be', 'start': 984, 'end': 1112, 'confidence': 0.99969, 'speaker': 'A', 'channel': None}, {'text': 'trying', 'start': 1136, 'end': 1368, 'confidence': 0.99914, 'speaker': 'A', 'channel': None}, {'text': 'to', 'start': 1424, 'end': 1640, 'confidence': 0.99989, 'speaker': 'A', 'channel': None}, {'text': 'prove', 'start': 1680, 'end': 2280, 'confidence': 0.73101, 'speaker': 'A', 'channel': None}
# ...

# %%
# total text
transcript.text
print("\n")
transcript.chapters
# Out:
# [Chapter(summary="Like all of a sudden I'd be trying to prove that I'm not crazy when I knew I wasn't crazy.", headline="Like all of a sudden I'd be trying to prove that I'm not crazy", gist='Are You Crazy or Not?', start=160, end=4760)]
# time: 3.03 ms (started: 2025-03-28 14:08:30 +00:00)

# %%
transcript.utterances
# Out:
# [Utterance(text="Like all of a sudden I'd be trying to prove that I'm not crazy when I knew I wasn't crazy.", start=160, end=4760, confidence=0.9704955, speaker='A', channel=None, words=[UtteranceWord(text='Like', start=160, end=272, confidence=0.98641, speaker='A', channel=None), UtteranceWord(text='all', start=272, end=408, confidence=0.9999, speaker='A', channel=None), UtteranceWord(text='of', start=416, end=504, confidence=0.99806, speaker='A', channel=None), UtteranceWord(text='a', start=512, end=584, confidence=0.9987, speaker='A', channel=None), UtteranceWord(text='sudden', start=592, end=776, confidence=0.99997, speaker='A', channel=None), UtteranceWord(text="I'd", start=808, end=968, confidence=0.98048, speaker='A', channel=None), UtteranceWord(text='be', start=984, end=1112, confidence=0.99969, speaker='A', channel=None), UtteranceWord(text='trying', start=1136, end=1368, confidence=0.99914, speaker='A', channel=None), UtteranceWord(text='to', start=1424, end=1640, confiden
# ...

# %%
if transcript.utterances is None:
    print("Aucun segment n'a été généré pour cette transcription.")
else:
    for segment in transcript.utterances:
        debut = segment.start / 1000  # Convertir les millisecondes en secondes
        fin = segment.end / 1000
        texte = segment.text
        print(f"[{debut:.2f}s - {fin:.2f}s] {texte}")
# Out:
# [0.16s - 4.76s] Like all of a sudden I'd be trying to prove that I'm not crazy when I knew I wasn't crazy.
# time: 827 µs (started: 2025-03-28 14:08:36 +00:00)

# %% [markdown]
# ### Export SRT or VTT

# %%
vtt = transcript.export_subtitles_vtt()
with open(f"transcript_{transcript.id}.vtt", "w") as vtt_file:
  vtt_file.write(vtt)
# Out:
# time: 1.81 s (started: 2025-03-27 19:38:43 +00:00)

# %%
srt = transcript.export_subtitles_srt(
  # Optional: Customize the maximum number of characters per caption
  chars_per_caption=64
  )
with open(f"transcript_{transcript.id}.srt", "w") as srt_file:
  srt_file.write(srt)
# Out:
# time: 1.11 s (started: 2025-03-27 19:38:46 +00:00)

# %% [markdown]
# ### Export paragraphs and sentences

# %% [markdown]
# ### Export sentences

# %%
sentences = transcript.get_sentences()
for sentence in sentences:
  print(sentence)
  print()
# Out:
# text="Like all of a sudden I'd be trying to prove that I'm not crazy when I knew I wasn't crazy." start=160 end=4760 confidence=0.98641 speaker='A' channel=None words=[Word(text='Like', start=160, end=272, confidence=0.98641, speaker='A', channel=None), Word(text='all', start=272, end=408, confidence=0.9999, speaker='A', channel=None), Word(text='of', start=416, end=504, confidence=0.99806, speaker='A', channel=None), Word(text='a', start=512, end=584, confidence=0.9987, speaker='A', channel=None), Word(text='sudden', start=592, end=776, confidence=0.99997, speaker='A', channel=None), Word(text="I'd", start=808, end=968, confidence=0.98048, speaker='A', channel=None), Word(text='be', start=984, end=1112, confidence=0.99969, speaker='A', channel=None), Word(text='trying', start=1136, end=1368, confidence=0.99914, speaker='A', channel=None), Word(text='to', start=1424, end=1640, confidence=0.99989, speaker='A', channel=None), Word(text='prove', start=1680, end=2280, confidence=0.73101,
# ...

# %% [markdown]
# ### Each subtitle segment

# %%
print(transcript.json_response['words'])
# each subtitle segment
wordlevel_info = []
for chapter in transcript.json_response['words']:
  wordlevel_info.append({
      "word": chapter['text'],
      "start": chapter['start']/1000,
      "end": chapter['end'] /1000
  })

print(f"{wordlevel_info}")
# Out:
# [{'text': 'Like', 'start': 160, 'end': 272, 'confidence': 0.98641, 'speaker': 'A', 'channel': None}, {'text': 'all', 'start': 272, 'end': 408, 'confidence': 0.9999, 'speaker': 'A', 'channel': None}, {'text': 'of', 'start': 416, 'end': 504, 'confidence': 0.99806, 'speaker': 'A', 'channel': None}, {'text': 'a', 'start': 512, 'end': 584, 'confidence': 0.9987, 'speaker': 'A', 'channel': None}, {'text': 'sudden', 'start': 592, 'end': 776, 'confidence': 0.99997, 'speaker': 'A', 'channel': None}, {'text': "I'd", 'start': 808, 'end': 968, 'confidence': 0.98048, 'speaker': 'A', 'channel': None}, {'text': 'be', 'start': 984, 'end': 1112, 'confidence': 0.99969, 'speaker': 'A', 'channel': None}, {'text': 'trying', 'start': 1136, 'end': 1368, 'confidence': 0.99914, 'speaker': 'A', 'channel': None}, {'text': 'to', 'start': 1424, 'end': 1640, 'confidence': 0.99989, 'speaker': 'A', 'channel': None}, {'text': 'prove', 'start': 1680, 'end': 2280, 'confidence': 0.73101, 'speaker': 'A', 'channel': None}
# ...

# %%
wordlevel_info
# Out:
# [{'word': 'Like', 'start': 0.16, 'end': 0.272},
#  {'word': 'all', 'start': 0.272, 'end': 0.408},
#  {'word': 'of', 'start': 0.416, 'end': 0.504},
#  {'word': 'a', 'start': 0.512, 'end': 0.584},
#  {'word': 'sudden', 'start': 0.592, 'end': 0.776},
#  {'word': "I'd", 'start': 0.808, 'end': 0.968},
#  {'word': 'be', 'start': 0.984, 'end': 1.112},
#  {'word': 'trying', 'start': 1.136, 'end': 1.368},
#  {'word': 'to', 'start': 1.424, 'end': 1.64},
#  {'word': 'prove', 'start': 1.68, 'end': 2.28},
#  {'word': 'that', 'start': 2.44, 'end': 2.712},
#  {'word': "I'm", 'start': 2.736, 'end': 2.936},
#  {'word': 'not', 'start': 2.968, 'end': 3.112},
#  {'word': 'crazy', 'start': 3.136, 'end': 3.496},
#  {'word': 'when', 'start': 3.528, 'end': 3.672},
#  {'word': 'I', 'start': 3.696, 'end': 3.88},
#  {'word': 'knew', 'start': 3.92, 'end': 4.088},
#  {'word': 'I', 'start': 4.104, 'end': 4.232},
#  {'word': "wasn't", 'start': 4.256, 'end': 4.456},
# ...

# %% [markdown]
# ## Step4: Store word-level timestamps into JSON file

# %%
import json
with open('data.json', 'w') as f:
    json.dump(wordlevel_info, f,indent=4)
# Out:
# time: 2.02 ms (started: 2025-03-28 14:21:34 +00:00)

# %% [markdown]
# ## Step5: Correct and save JSON file if there are transcription errors or if you need to merge any words into phrases. Load the new edited JSON file with new word-level timestamps

# %%
import json

with open('data.json', 'r') as f:
    wordlevel_info_modified = json.load(f)
# Out:
# time: 1.42 ms (started: 2025-03-28 14:21:35 +00:00)

# %%
wordlevel_info_modified
# Out:
# [{'word': 'Like', 'start': 0.16, 'end': 0.272},
#  {'word': 'all', 'start': 0.272, 'end': 0.408},
#  {'word': 'of', 'start': 0.416, 'end': 0.504},
#  {'word': 'a', 'start': 0.512, 'end': 0.584},
#  {'word': 'sudden', 'start': 0.592, 'end': 0.776},
#  {'word': "I'd", 'start': 0.808, 'end': 0.968},
#  {'word': 'be', 'start': 0.984, 'end': 1.112},
#  {'word': 'trying', 'start': 1.136, 'end': 1.368},
#  {'word': 'to', 'start': 1.424, 'end': 1.64},
#  {'word': 'prove', 'start': 1.68, 'end': 2.28},
#  {'word': 'that', 'start': 2.44, 'end': 2.712},
#  {'word': "I'm", 'start': 2.736, 'end': 2.936},
#  {'word': 'not', 'start': 2.968, 'end': 3.112},
#  {'word': 'crazy', 'start': 3.136, 'end': 3.496},
#  {'word': 'when', 'start': 3.528, 'end': 3.672},
#  {'word': 'I', 'start': 3.696, 'end': 3.88},
#  {'word': 'knew', 'start': 3.92, 'end': 4.088},
#  {'word': 'I', 'start': 4.104, 'end': 4.232},
#  {'word': "wasn't", 'start': 4.256, 'end': 4.456},
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# time: 23.1 s (started: 2025-03-28 14:22:05 +00:00)

# %% [markdown]
# ## Step6: Convert word-level timestamps JSON to line-level timestamps JSON. We want to display one line at a time and highlight words in it as they are spoken so we do this transformation.

# %%
def split_text_into_lines(data):

    MaxChars = 10
    #maxduration in seconds
    MaxDuration = 3.0
    #Split if nothing is spoken (gap) for these many seconds
    MaxGap = 1.5

    subtitles = []
    line = []
    line_duration = 0
    line_chars = 0


    for idx,word_data in enumerate(data):
        word = word_data["word"]
        start = word_data["start"]
        end = word_data["end"]

        line.append(word_data)
        line_duration += end - start

        temp = " ".join(item["word"] for item in line)


        # Check if adding a new word exceeds the maximum character count or duration
        new_line_chars = len(temp)

        duration_exceeded = line_duration > MaxDuration
        chars_exceeded = new_line_chars > MaxChars
        if idx>0:
          gap = word_data['start'] - data[idx-1]['end']
          # print (word,start,end,gap)
          maxgap_exceeded = gap > MaxGap
        else:
          maxgap_exceeded = False


        if duration_exceeded or chars_exceeded or maxgap_exceeded:
            if line:
                subtitle_line = {
                    "word": " ".join(item["word"] for item in line),
                    "start": line[0]["start"],
                    "end": line[-1]["end"],
                    "textcontents": line
                }
                subtitles.append(subtitle_line)
                line = []
                line_duration = 0
                line_chars = 0


    if line:
        subtitle_line = {
            "word": " ".join(item["word"] for item in line),
            "start": line[0]["start"],
            "end": line[-1]["end"],
            "textcontents": line
        }
        subtitles.append(subtitle_line)

    return subtitles
# Out:
# time: 12.2 ms (started: 2025-03-28 14:23:37 +00:00)

# %%
linelevel_subtitles = split_text_into_lines(wordlevel_info_modified)
print (linelevel_subtitles)
# Out:
# [{'word': 'Like all of', 'start': 0.16, 'end': 0.504, 'textcontents': [{'word': 'Like', 'start': 0.16, 'end': 0.272}, {'word': 'all', 'start': 0.272, 'end': 0.408}, {'word': 'of', 'start': 0.416, 'end': 0.504}]}, {'word': "a sudden I'd", 'start': 0.512, 'end': 0.968, 'textcontents': [{'word': 'a', 'start': 0.512, 'end': 0.584}, {'word': 'sudden', 'start': 0.592, 'end': 0.776}, {'word': "I'd", 'start': 0.808, 'end': 0.968}]}, {'word': 'be trying to', 'start': 0.984, 'end': 1.64, 'textcontents': [{'word': 'be', 'start': 0.984, 'end': 1.112}, {'word': 'trying', 'start': 1.136, 'end': 1.368}, {'word': 'to', 'start': 1.424, 'end': 1.64}]}, {'word': "prove that I'm", 'start': 1.68, 'end': 2.936, 'textcontents': [{'word': 'prove', 'start': 1.68, 'end': 2.28}, {'word': 'that', 'start': 2.44, 'end': 2.712}, {'word': "I'm", 'start': 2.736, 'end': 2.936}]}, {'word': 'not crazy when', 'start': 2.968, 'end': 3.672, 'textcontents': [{'word': 'not', 'start': 2.968, 'end': 3.112}, {'word': 'crazy', 
# ...

# %%
for line in linelevel_subtitles:
  json_str = json.dumps(line, indent=4)
  print(json_str)
# Out:
# {
#     "word": "Like all of",
#     "start": 0.16,
#     "end": 0.504,
#     "textcontents": [
#         {
#             "word": "Like",
#             "start": 0.16,
#             "end": 0.272
#         },
#         {
#             "word": "all",
#             "start": 0.272,
#             "end": 0.408
#         },
#         {
#             "word": "of",
#             "start": 0.416,
#             "end": 0.504
#         }
#     ]
# }
# {
#     "word": "a sudden I'd",
#     "start": 0.512,
#     "end": 0.968,
#     "textcontents": [
#         {
#             "word": "a",
#             "start": 0.512,
#             "end": 0.584
#         },
#         {
#             "word": "sudden",
#             "start": 0.592,
#             "end": 0.776
#         },
#         {
#             "word": "I'd",
#             "start": 0.808,
#             "end": 0.968
#         }
#     ]
# }
# {
#     "word": "be trying to",
#     "start": 0.984,
#     "end": 1.64,
#     "textcontents": [
#         {
# ...

# %% [markdown]
# ## Step7: Use Moviepy to create an audiogram with word-level highlights as they are spoken

# %%
# !pip install moviepy==2.0.0.dev2
# !pip install imageio==2.25.1
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.1/400.1 kB 19.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for moviepy: filename=moviepy-2.0.0.dev2-py3-none-any.whl size=111664 sha256=b008fe77bf78e2908a340580657e1dc5ec0d0b64ee2dcb5a59e47d9a448c5272
#   Stored in directory: /root/.cache/pip/wheels/31/50/ca/52880c49f16c0abe1b5b57b81585f45f061f458b10c377ee1c
# Successfully built moviepy
# ...
#   Attempting uninstall: moviepy
#     Found existing installation: moviepy 1.0.3
#     Uninstalling moviepy-1.0.3:
#       Successfully uninstalled moviepy-1.0.3
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 53.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: imageio
#     Found existing installation: imageio 2.37.0
#     Uninstalling imageio-2.37.0:
#       Successfully uninstalled imageio-2.37.0
# ...

# %%
# !apt install imagemagick --quiet
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript gsfonts imagemagick-6-common
#   imagemagick-6.q16 libdjvulibre-text libdjvulibre21 libfftw3-double3 libgs9 libgs9-common libidn12
#   libijs-0.35 libjbig2dec0 libjxr-tools libjxr0 liblqr-1-0 libmagickcore-6.q16-6
#   libmagickcore-6.q16-6-extra libmagickwand-6.q16-6 libnetpbm10 libwmflite-0.2-7 netpbm
#   poppler-data
# Suggested packages:
#   fonts-noto fonts-freefont-otf | fonts-freefont-ttf fonts-texgyre ghostscript-x imagemagick-doc
#   autotrace cups-bsd | lpr | lprng enscript gimp gnuplot grads hp2xx html2ps libwmf-bin mplayer
#   povray radiance sane-utils texlive-base-bin transfig ufraw-batch libfftw3-bin libfftw3-dev
#   inkscape poppler-utils fonts-japanese-mincho | fonts-ipafont-mincho fonts-japanese-gothic
# ...

# %%
# !cat /etc/ImageMagick-6/policy.xml | sed 's/none/read,write/g'> /etc/ImageMagick-6/policy.xml
# Out:
# time: 104 ms (started: 2025-03-28 14:24:39 +00:00)

# %%
from moviepy.editor import TextClip, CompositeVideoClip, ColorClip
import numpy as np


def create_caption(textJSON, framesize,font = "/content/N8n/THEBOLDFONT-FREEVERSION.ttf",fontsize=60, color='white', bgcolor='yellow'):
    wordcount = len(textJSON['textcontents'])
    full_duration = textJSON['end']-textJSON['start']

    word_clips = []
    xy_textclips_positions =[]

    x_pos = 0
    y_pos = 0
    # max_height = 0
    frame_width = framesize[0]
    frame_height = framesize[1]
    x_buffer = frame_width*0.15
    y_buffer = frame_height*0.4

    space_width = ""
    space_height = ""

    for index,wordJSON in enumerate(textJSON['textcontents']):
      duration = wordJSON['end']-wordJSON['start']
      word_clip = TextClip(wordJSON['word'], font = font,fontsize=fontsize, color=color, stroke_color="black", stroke_width=3).set_start(textJSON['start']).set_duration(full_duration)
      word_clip_space = TextClip(" ", font = font,fontsize=fontsize, color=color).set_start(textJSON['start']).set_duration(full_duration)
      word_width, word_height = word_clip.size
      space_width,space_height = word_clip_space.size
      if x_pos + word_width+ space_width > frame_width-2*x_buffer:
            # Move to the next line
            x_pos = 0
            y_pos = y_pos+ word_height+40



            # Store info of each word_clip created
            xy_textclips_positions.append({
                "x_pos":x_pos+x_buffer,
                "y_pos": y_pos+y_buffer,
                "width" : word_width,
                "height" : word_height,
                "word": wordJSON['word'],
                "start": wordJSON['start'],
                "end": wordJSON['end'],
                "duration": duration
            })

            word_clip = word_clip.set_position((x_pos+x_buffer, y_pos+y_buffer))
            word_clip_space = word_clip_space.set_position((x_pos+ word_width +x_buffer, y_pos+y_buffer))
            x_pos = word_width + space_width
      else:
            # Store info of each word_clip created
            xy_textclips_positions.append({
                "x_pos":x_pos+x_buffer,
                "y_pos": y_pos+y_buffer,
                "width" : word_width,
                "height" : word_height,
                "word": wordJSON['word'],
                "start": wordJSON['start'],
                "end": wordJSON['end'],
                "duration": duration
            })

            word_clip = word_clip.set_position((x_pos+x_buffer, y_pos+y_buffer))
            word_clip_space = word_clip_space.set_position((x_pos+ word_width+ x_buffer, y_pos+y_buffer))

            x_pos = x_pos + word_width+ space_width


      word_clips.append(word_clip)
      word_clips.append(word_clip_space)


    for highlight_word in xy_textclips_positions:

      word_clip_highlight = TextClip(highlight_word['word'], font = font,fontsize=fontsize, color=color,bg_color = bgcolor).set_start(highlight_word['start']).set_duration(highlight_word['duration'])
      word_clip_highlight = word_clip_highlight.set_position((highlight_word['x_pos'], highlight_word['y_pos']))
      word_clips.append(word_clip_highlight)

    return word_clips
# Out:
# time: 11.4 ms (started: 2025-03-28 16:24:10 +00:00)

# %%
from moviepy.editor import TextClip, CompositeVideoClip, concatenate_videoclips,VideoFileClip, ColorClip
frame_size = (1080,1929)

all_linelevel_splits=[]

for line in linelevel_subtitles:
  out = create_caption(line,frame_size)
  all_linelevel_splits.extend(out)



# Load the input video
input_video = VideoFileClip(videofilename)
# Get the duration of the input video
input_video_duration = input_video.duration
# Create a color clip with the given frame size, color, and duration
background_clip = ColorClip(size=frame_size, color=(0, 0, 0)).set_duration(input_video_duration)

# If you want to overlay this on the original video uncomment this and also change frame_size, font size and color accordingly.
final_video = CompositeVideoClip([input_video] + all_linelevel_splits)

# final_video = CompositeVideoClip([background_clip] + all_linelevel_splits)

# Set the audio of the final video to be the same as the input video
final_video = final_video.set_audio(input_video.audio)

# Save the final clip as a video file with the audio included
final_video.write_videofile("output.mp4", fps=60, codec="libx264", audio_codec="aac")
# Out:
# Moviepy - Building video output.mp4.
# MoviePy - Writing audio in outputTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video output.mp4
# Moviepy - Done !
# Moviepy - video ready output.mp4
# time: 42.9 s (started: 2025-03-28 16:24:28 +00:00)

# %% [markdown]
# ## Step8: Visualize the final Descript like audiogram video

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open("output.mp4",'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
# time: 35.6 ms (started: 2025-03-28 16:25:17 +00:00)
